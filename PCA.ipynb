# %%
import pandas as pd
df=pd.read_csv("/content/Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.drop(['Id'],axis=1,inplace=True)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
x_train=pca.fit_transform(x_train)
x_test=pca.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-2.73819523e+00,  4.44717255e-01],
#        [-2.25818211e+00,  2.68854777e+00],
#        [ 9.12885398e-01,  5.39533171e-01],
#        [-2.28408660e+00,  1.23794115e-01],
#        [-2.50333080e+00, -4.93987129e-01],
#        [ 1.62128655e+00, -8.64495547e-01],
#        [ 7.66870614e-01,  6.23760161e-01],
#        [-2.13205022e+00,  5.21310088e-01],
#        [-2.35548850e+00,  6.38867257e-01],
#        [-2.59695256e+00,  1.78826269e+00],
#        [ 1.21112362e+00, -6.70407909e-01],
#        [ 4.59996666e-01,  8.72204121e-01],
#        [ 1.08598557e+00,  5.54740492e-01],
#        [-2.18620218e+00,  1.48104061e+00],
#        [-2.13725697e+00,  1.04013863e+00],
#        [ 9.13006432e-02, -1.56110652e+00],
#        [ 1.16360688e+00, -2.62651322e-01],
#        [ 1.38445119e+00,  4.58505354e-01],
#        [ 9.15488771e-01,  2.80118900e-01],
#        [ 2.27440925e+00,  1.97384186e+00],
#        [ 2.77456674e-01, -3.65903398e-01],
#        [ 2.78607865e+00,  8.55045855e-01],
#        [ 3.96602708e-01, -1.75027185e-01],
#        [-2.22772690e+00,  4.72772587e-01],
#        [ 2.93831284e+00,  4.68500193e-01],
#        [ 2.15880820e-01, -7.75352903e-01],
#        [-2.09996531e+00,  3.06677917e-01],
#        [-2.24959614e+00,  4.33809308e-01],
#        [-2.11017158e+00,  1.13957294e+00],
#        [-2.70601216e-02, -2.64917880e+00],
#        [ 1.38401656e+00, -4.50438528e-01],
#        [-2.18479388e+00,  1.29427214e-01],
#        [-1.89819846e+00, -6.33904166e-01],
#        [-1.77664687e+00,  8.16194104e-02],
#        [ 3.45242529e-01, -8.38072139e-01],
#        [-2.12944685e+00,  2.61895816e-01],
#        [ 1.38466741e-01, -1.62723149e-01],
#        [ 2.43410292e+00,  2.61519334e+00],
#        [-2.34507500e+00, -3.98789828e-01],
#        [ 6.23449793e-01, -1.30726695e-01],
#        [ 1.31961935e+00, -1.13488013e+00],
#        [-2.43368784e+00,  2.14869308e+00],
#        [ 9.67634218e-01,  4.59677821e-02],
#        [ 1.21112362e+00, -6.70407909e-01],
#        [ 6.33853874e-01, -1.74768335e+00],
#        [ 2.71444490e-01, -2.68346786e-01],
#        [ 1.39968521e+00,  1.04944257e+00],
#        [ 4.77198200e-01, -1.73950522e+00],
#        [-2.05381188e+00,  1.48855141e+00],
#        [-2.88802716e-01, -2.01467079e+00],
#        [ 1.65279342e+00, -3.86693706e-01],
#        [ 1.48533462e+00, -1.17856873e-02],
#        [ 3.09541582e-01, -5.80535568e-01],
#        [ 1.51221278e+00,  2.92410684e-01],
#        [ 1.11022137e+00, -1.35871602e+00],
#        [ 7.48608010e-01, -3.74070935e-02],
#        [ 1.02839522e+00, -5.45154218e-01],
#        [ 1.00434783e+00,  4.94108124e-03],
#        [-1.87551437e+00,  4.05630618e-01],
#        [ 5.26760443e-01, -3.95774066e-01],
#        [ 4.32076257e-01, -1.54626970e+00],
#        [-2.18178070e+00,  1.85940814e+00],
#        [ 3.95580630e-01, -9.70836630e-01],
#        [ 2.24150008e+00,  6.08602952e-01]])

# %%
x_test
# Out:
# array([[ 0.41307948, -0.4869899 ],
#        [-1.99933611,  1.50264781],
#        [ 3.10723994, -0.23636193],
#        [ 0.46375712, -0.28696308],
#        [ 1.05103276, -0.19829282],
#        [-1.99134241,  0.51838566],
#        [-0.24391038, -0.45140026],
#        [ 1.75804409,  0.55315895],
#        [ 0.92792564, -1.73717225],
#        [ 0.00351145, -0.81806161],
#        [ 1.2226949 ,  0.5940935 ],
#        [-2.44963208, -0.61117531],
#        [-2.19315363,  0.76470737],
#        [-2.39991732, -0.35397036],
#        [-2.452929  ,  1.267224  ],
#        [ 0.60845251,  0.71036498],
#        [ 1.701699  ,  0.16516114],
#        [-0.10637136, -1.34045957],
#        [ 0.16506502, -0.63692112],
#        [ 1.66688642, -0.30976894],
#        [-2.46770883, -0.20867192],
#        [ 0.84134241, -0.01234194],
#        [-2.21686453,  0.35973882],
#        [ 1.59054187, -0.31630189],
#        [ 2.26853836,  2.4480689 ],
#        [ 1.70960365,  0.25501906],
#        [ 1.76479372, -0.87427446],
#        [ 1.90914438,  0.72631137],
#        [-2.29694299, -0.59810941],
#        [-2.35524408, -0.38764478]])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.svm import SVC

sv1=SVC(kernel='linear')
sv2=SVC(kernel='poly')
sv3=SVC(kernel='rbf')
sv1.fit(x_train,y_train)
y_predict1=sv1.predict(x_test)

l=[sv1,sv2,sv3]
for i in l:
  i.fit(x_train,y_train)
  y_predict=i.predict(x_test)
  print(accuracy_score(y_test,y_predict))
  print(confusion_matrix(y_test,y_predict))
  print(classification_report(y_test,y_predict))
# Out:
# 0.9333333333333333
# [[10  0  0]
#  [ 0  8  1]
#  [ 0  1 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.89      0.89      0.89         9
#            2       0.91      0.91      0.91        11
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30
#
# 0.9333333333333333
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  2  9]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.82      1.00      0.90         9
#            2       1.00      0.82      0.90        11
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.93        30
# weighted avg       0.95      0.93      0.93        30
#
# 0.9333333333333333
# [[10  0  0]
#  [ 0  8  1]
#  [ 0  1 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.89      0.89      0.89         9
#            2       0.91      0.91      0.91        11
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30
